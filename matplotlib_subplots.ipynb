# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#data = pd.read_csv('\Users\Rachel Veenstra\Desktop\Coding\introcoding-spring-2019\Datasets\global_wheat.csv')
import glob

glob.os.chdir('/Users/Rachel Veenstra/Desktop/Coding/introcoding-spring-2019/Datasets')
df = pd.read_csv('global_wheat.csv')
df.head(5)
# Out:
#    year  Argentina_area_has  Argentina_production_ton  Argentina_yield_hg_ha  \
# 0  1961             4420900                   5725000                  12950
# 1  1962             3744700                   5700000                  15222
# 2  1963             5676000                   8940000                  15751
# 3  1964             6135400                  11260000                  18353
# 4  1965             4601200                   6079000                  13212
#
#    Australia_area_has  Australia_production_ton  Australia_yield_hg_ha  \
# 0             5958110                   6727190                  11291
# 1             6664680                   8352910                  12533
# 2             6666680                   8924460                  13387
# 3             7251500                  10037000                  13841
# 4             7087980                   7067060                   9970
#
# ...

# %%
plt.figure()
plt.subplot(2,1,1)
plt.plot(df.year, df.Argentina_yield_hg_ha)
plt.ylabel('Yield hg/ha')

plt.subplot(2,1,2)
plt.plot(df.year, df.US_yield_hg_ha)
plt.ylabel('Yield hg/ha')

plt.show()

# %%
# yyplot
plt.figure()
ax1 = plt.subplot()
ax1.plot(df.year, df.Argentina_yield_hg_ha, '--g')

ax2 = ax1.twinx() ## x-axis is shared
ax2.plot(df.year, df.US_yield_hg_ha, '-b')

ax1.set_xlabel('Years')
ax1.set_ylabel('Argentina Yields hg $\mathregular{ha^{-1}}$', color='g')
ax2.set_ylabel('United States Yields hg $\mathregular{ha^{-1}}$', color='b')

plt.show()
